# %%
# %run ans_test_code.ipynb #this allows the code to be hidden from the user while the test is running
# Out:
# 8 / 64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_16408\2196641589.py:139
#     125     #ranking_df = pd.read_excel('https://docs.google.com/spreadsheets/d/1b3gfAoqqrDOp774U2zbWLt2FCBYU-XetmoyhIkJSwCg/edit?resourcekey#gid=1550936854', usecols='B, G', engine='openpyxl')
#     126     #rankings = ranking_df['correct'].rank(method='min', ascending=False)
#     127     #ranking = rankings[ranking_df['score'] == score].iloc[0]
#    (...)
#     134              #f"{ranking:.0f} out of {total_entries} testees.<br>Currently the highest score is {max_value}.<br>"
#     135              #f"Feel free to try the test again for a better result!</p>"))
#     138 if __name__ == '__main__':
# --> 139     main()
#
# File ~\AppData\Local\Temp\ipykernel_16408\2196641589.py:114, in main()
# ...
